# %%
import matplotlib.pyplot as plt
import pandas as pd
data =  pd.read_csv('E:\\Twitter paper\\DATASET_CREATED\\Zomato_ENGLISH.csv')
#data =  pd.read_csv('E:\\Zomato_ENGLISH.csv')

print(data['Tweet_source'].unique())
value =data['Tweet_source'].value_counts()
df= pd.DataFrame(value)
df.to_csv("E:\\Twitter paper\\DATASET_CREATED\\souce.csv", index=False)
print(df)
# Out:
# ['Twitter for Android' 'TweetDeck' 'Twitter Web Client' 'RT/FAV Bot CHN'
#  'Twitter for iPhone' 'Twitter Web App' 'Zomato' 'Facebook' 'Buffer'
#  'Flamingo for Android' 'Twitter for iPad' 'Mobile Web (M2)']
#                       Tweet_source
# Twitter for Android            458
# Twitter for iPhone             146
# TweetDeck                      106
# Twitter Web Client              96
# Twitter Web App                 68
# Zomato                           6
# Twitter for iPad                 6
# Facebook                         1
# Flamingo for Android             1
# Buffer                           1
# Mobile Web (M2)                  1
# RT/FAV Bot CHN                   1

# %%
label=['Twitter Android', 'Twitter iPhone','TweetDeck','Twitter Web Client' ,'Twitter Web App','Zomato','Twitter for iPad',
       'Facebook' ,
       'Flamingo for Android', 'Buffer' ,'Mobile Web (M2) ','RT/FAV Bot CHN' ]
lis=[458,146,106,96,68,6,6,1,1,1,1,1]

plt.pie(lis,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title(" pie chart ")
plt.show()

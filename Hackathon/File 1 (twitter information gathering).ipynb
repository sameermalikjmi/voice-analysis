# %%
import tweepy
from IPython.display import display
from textblob import TextBlob
import pandas as pd 
import json
import re
import time
import nltk

CONSUMER_KEY    = '7H0tnWTrwJUaWBGY5RCub8LEW'
CONSUMER_SECRET = 'HxuA9wyMy48WqSrFYcdeB9fMfibPvPuMVrKSILDQ2q9tR0dsRY'
ACCESS_TOKEN  = '902769774022840320-Tg7ZYxxDVrAwKno9ctuMie8bNxv5nRH'
ACCESS_SECRET = 'a8DNJVG9B2y2G7B6fxUPcl4zzbLjsalDDhP2DAGgyRlV1'

auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN,ACCESS_SECRET)

twitter_api=tweepy.API(auth, wait_on_rate_limit=True)
print(twitter_api)
  
def clean_tweet(tweet):
   
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
  
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1
    
searchterm = input("enter the keyword/hastag to search about: ")
no_of_searchitems = int(input('enter the no. how many tweets you want to search and analysis: '))

tweets = tweepy.Cursor(twitter_api.search,q=searchterm,tweet_mode='extended').items(no_of_searchitems)
Tweet_text = []
#Tweet_length=[]
Tweet_id=[]
#Tweet_date=[]
#Tweet_locate=[]
sent=[]
senti=[]
Tweet_user_followers_count=[]
#Tweet_user_friend_count=[]
#Tweet_user_screen_name=[]
Tweet_user_verified=[]
#Tweet_user_name=[]
Tweet_favourite_count=[]
Tweet_language=[]
Tweet_retwet_count=[]
Tweet_source=[]
Tweet_user_id=[]
#Tweet_user_geoenabled=[]

for tweet in tweets:
    
  #  Tweet_locate.append(tweet.user.location)
    Tweet_user_followers_count.append(tweet.user.followers_count)
   # Tweet_user_friend_count.append(tweet.user.friends_count)
 #   Tweet_user_screen_name.append(tweet.user.screen_name)
    Tweet_user_verified.append(tweet.user.verified)
#    Tweet_user_name.append(tweet.user.name)
    Tweet_favourite_count.append(tweet.favorite_count)
    Tweet_language.append(tweet.lang)
    Tweet_retwet_count.append(tweet.retweet_count)
    Tweet_source.append(tweet.source)
#    Tweet_user_geoenabled.append(tweet.user.geo_enabled)
    Tweet_user_id.append(tweet.user.id)
    Tweet_text.append(tweet.full_text)   
    senti.append(analize_sentiment(tweet.full_text))
    sent.append(TextBlob(tweet.full_text).sentiment.polarity)
#    Tweet_length.append(len(tweet.full_text))
    Tweet_id.append(tweet.id)
#    Tweet_date.append(tweet.created_at)
    
   # file={'Tweets':Tweet_text,'sent_value':sent,'ID':Tweet_id,'sentiments':senti,
    #      'Tweet_favourite_count':Tweet_favourite_count,'Tweet_user_followers_count':Tweet_user_followers_count,
   #       'Tweet_retwet_count':Tweet_retwet_count,'Tweet_user_verified':Tweet_user_verified,
     #     'Tweet_language':Tweet_language,'Tweet_source':Tweet_source,
      #    'Tweet_user_id':Tweet_user_id}
    
    file={'Tweet ID':Tweet_id,'Tweet_user_id':Tweet_user_id,'Tweet_language':Tweet_language,'Tweet_source':Tweet_source,
          'Tweet_user_verified':Tweet_user_verified,'Tweet_favourite_count':Tweet_favourite_count,
          'Tweet_user_followers_count':Tweet_user_followers_count,'Tweet_retwet_count':Tweet_retwet_count,
          'Tweets':Tweet_text,'sent_value':sent,'sentiments':senti }
    data= pd.DataFrame(file)
    
    data.to_csv('C:\Data_hackaton\sameeer_daddy.csv',index=False)
    
print(data)
       
print("--------------------Data added to the excel file--------------------------")
# Out:
# ...
# enter the keyword/hastag to search about: @HSBC
# enter the no. how many tweets you want to search and analysis: 100
#                Tweet ID        Tweet_user_id Tweet_language  \
# 0   1143556477619187713            870544742             en
# 1   1143556196953022464            198995705             es
# 2   1143553717289050113            164783615             es
# 3   1143547264230555648            130352473             es
# 4   1143540412528902144   956922244323860482             en
# 5   1143540342324678656            172461978             en
# 6   1143538163761258497            143025236             en
# 7   1143535058374070273           1367434538             en
# 8   1143534404100382720  1129408951517372417             es
# 9   1143529290778042368   780292093839220736             en
# 10  1143527768291856384             95711125             en
# 11  1143527416062709760   731109819743141888             da
# 12  1143525875901706240             52400185             en
# ...
